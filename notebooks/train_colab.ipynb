# %% [markdown]
# # MailGuard AI — Transformer Training (GPU)
#
# **Steps:** Run all cells on a GPU runtime → wait a few minutes → download `trained_model.zip`.

# %%
# 1. Check GPU
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    print("⚠️ Go to Runtime > Change runtime type > GPU")

# %%
# 2. Clone repo
# !git clone https://github.com/Ilyes-Jamoussi/mailguard-ai.git
# %cd mailguard-ai

# %%
# 3. Install dependencies
# !pip install -r requirements.txt -q

# %%
# 4. Download & prepare dataset (SpamAssassin public corpus)
# !python -m src.prepare_data

# %%
# 5. Train the full Transformer model
# !python -m src.train

# %%
# 6. Download trained model
# !zip -r trained_model.zip models/
from google.colab import files

files.download("trained_model.zip")
